# %%
import pandas as pd

# %%
df = pd.read_csv("House.csv")

# %%
df.isnull().sum()
# Out:
# Income        1
# Age           3
# Rooms         1
# Bedrms        1
# Population    3
# AveOccup      1
# Latitude      3
# Longitude     1
# Price         1
# dtype: int64

# %%
df = df.dropna()

# %%
df.corr()
# Out:
#               Income       Age     Rooms    Bedrms  Population  AveOccup  \
# Income      1.000000 -0.197005  0.324804 -0.065456    0.044035  0.026461
# Age        -0.197005  1.000000 -0.180917 -0.084575   -0.294598  0.015128
# Rooms       0.324804 -0.180917  1.000000  0.843106   -0.068519 -0.005257
# Bedrms     -0.065456 -0.084575  0.843106  1.000000   -0.069295 -0.006599
# Population  0.044035 -0.294598 -0.068519 -0.069295    1.000000  0.070105
# AveOccup    0.026461  0.015128 -0.005257 -0.006599    0.070105  1.000000
# Latitude   -0.077272  0.005537  0.121485  0.073354   -0.113759  0.001921
# Longitude  -0.009722 -0.101026 -0.029636  0.013278    0.101151  0.002293
# Price       0.644719  0.063328  0.109639 -0.061881    0.015452 -0.021036
#
#             Latitude  Longitude     Price
# Income     -0.077272  -0.009722  0.644719
# Age         0.005537  -0.101026  0.063328
# Rooms       0.121485  -0.029636  0.109639
# Bedrms      0.073354   0.013278 -0.061881
# Population -0.113759   0.101151  0.015452
# AveOccup    0.001921   0.002293 -0.021036
# Latitude    1.000000  -0.924068 -0.149535
# Longitude  -0.924068   1.000000 -0.046215
# Price      -0.149535  -0.046215  1.000000

# %%
top_features = df.corr()["Price"].drop("Price").abs().sort_values(ascending=False).head(3).index.tolist()
print(top_features)
# Out:
# ['Income', 'Latitude', 'Rooms']

# %%
X = df[top_features]
y = df["Price"]
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.2)
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, y_pred)
# Out:
# 0.5323668987998755
